# %% [markdown]
# # 🚰 Monitoreo de *Data Drift* y *Concept Drift* — Planta 1
#
# Notebook listo para correr con **todas las columnas numéricas** del archivo CSV.
#
# **Incluye:**
# - BaseLine configurable (por fechas o automático)
# - *Univariado* con Evidently (PSI/KS/AD) + Reporte HTML
# - *Multivariado* con MMD (alibi-detect)
# - PCA → **Hotelling T²** y **Q (SPE)**
# - KPI (si existe) → **Page–Hinkley** (concept drift)
# - Anomalías (IsolationForest + LOF) y consolidado por ventanas
# - Gráficas rápidas y *semaforo* por ventana
#
# **Requisitos:** Python 3.9+ y acceso a internet para instalar dependencias.
#
# **Archivos generados:**
# - `planta1_univar.html` (Evidently)
# - `planta1_kpi_ph.csv` (flags KPI Page–Hinkley)
# - `planta1_ventanas.csv` (resumen por ventana con MMD/T²/Q/outliers/semaforo)

# %%
# !pip install --upgrade pip
# Paquetes principales (bloques separados por compatibilidad)
# !pip install evidently==0.7.14
# !pip install alibi-detect scikit-learn pyod river hotelling
# !pip install pandas numpy matplotlib
# Out:
# Collecting evidently==0.7.14
#   Downloading evidently-0.7.14-py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#      -------- ------------------------------- 0.9/4.3 MB 13.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.9/4.3 MB 15.1 MB/s eta 0:00:01
#      -------------------------------- ------- 3.5/4.3 MB 24.9 MB/s eta 0:00:01
#      ---------------------------------------  4.3/4.3 MB 22.8 MB/s eta 0:00:01
#      ---------------------------------------- 4.3/4.3 MB 19.6 MB/s eta 0:00:00
# Collecting nltk>=3.6.7
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------  1.5/1.5 MB 48.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (2.2.6)
# Collecting deprecation>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting uuid6>=2024.7.10
#   Downloading uuid6-2025.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: urllib3>=1.26.19 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (2.5.0)
# Collecting watchdog>=3.0.0
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
#      ---------------------------------------- 0.0/79.1 kB ? eta -:--:--
#      ---------------------------------------- 79.1/79.1 kB 4.3 MB/s eta 0:00:00
# Collecting typer>=0.3
#   Downloading typer-0.17.4-py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.6 kB ? eta -:--:--
#      ---------------------------------------- 46.6/46.6 kB ? eta 0:00:00
# Collecting cryptography>=43.0.1
#   Downloading cryptography-45.0.7-cp37-abi3-win_amd64.whl (3.4 MB)
#      ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#      ---------------- ----------------------- 1.4/3.4 MB 43.9 MB/s eta 0:00:01
#      ------------------------------- -------- 2.7/3.4 MB 34.0 MB/s eta 0:00:01
#      ---------------------------------------  3.4/3.4 MB 31.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.4/3.4 MB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.12.2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (0.14.5)
# Collecting typing-inspect>=0.9.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (6.0.2)
# Collecting iterative-telemetry>=0.0.5
#   Downloading iterative_telemetry-0.0.10-py3-none-any.whl (10 kB)
# Collecting litestar>=2.8.3
#   Downloading litestar-2.17.0-py3-none-any.whl (564 kB)
#      ---------------------------------------- 0.0/564.3 kB ? eta -:--:--
#      ------------------------------------- 564.3/564.3 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (1.7.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (1.15.3)
# Collecting uvicorn[standard]>=0.22.0
#   Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
#      ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#      ---------------------------------------- 66.4/66.4 kB ? eta 0:00:00
# Collecting plotly<6,>=5.10.0
#   Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#      ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/19.1 MB 5.1 MB/s eta 0:00:04
#      ---------------------------------------- 0.2/19.1 MB 3.1 MB/s eta 0:00:07
#       --------------------------------------- 0.5/19.1 MB 3.6 MB/s eta 0:00:06
#      -- ------------------------------------- 1.1/19.1 MB 6.4 MB/s eta 0:00:03
#      ----- ---------------------------------- 2.5/19.1 MB 11.2 MB/s eta 0:00:02
#      -------- ------------------------------- 4.1/19.1 MB 16.5 MB/s eta 0:00:01
#      ------------ --------------------------- 5.9/19.1 MB 18.8 MB/s eta 0:00:01
#      --------------- ------------------------ 7.6/19.1 MB 21.1 MB/s eta 0:00:01
#      ------------------- -------------------- 9.2/19.1 MB 23.6 MB/s eta 0:00:01
#      ----------------------- --------------- 11.3/19.1 MB 36.4 MB/s eta 0:00:01
#      --------------------------- ----------- 13.3/19.1 MB 38.5 MB/s eta 0:00:01
#      ------------------------------ -------- 15.0/19.1 MB 38.5 MB/s eta 0:00:01
#      --------------------------------- ----- 16.6/19.1 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  18.9/19.1 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  19.0/19.1 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------  19.0/19.1 MB 38.6 MB/s eta 0:00:01
#      --------------------------------------- 19.1/19.1 MB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas[parquet]>=1.3.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (2.3.2)
# Collecting rich>=13
#   Downloading rich-14.1.0-py3-none-any.whl (243 kB)
#      ---------------------------------------- 0.0/243.4 kB ? eta -:--:--
#      ------------------------------------- 243.4/243.4 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2024.7.4 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (2025.8.3)
# Requirement already satisfied: requests>=2.32.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from evidently==0.7.14) (2.32.5)
# Collecting pydantic>=1.10.16
#   Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#      ---------------------------------------- 0.0/444.8 kB ? eta -:--:--
#      ------------------------------------- 444.8/444.8 kB 29.0 MB/s eta 0:00:00
# Collecting fsspec>=2024.6.1
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ---------------------------------------- 0.0/199.3 kB ? eta -:--:--
#      ---------------------------------------- 199.3/199.3 kB ? eta 0:00:00
# Collecting ujson>=5.4.0
#   Downloading ujson-5.11.0-cp310-cp310-win_amd64.whl (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      ---------------------------------------- 43.7/43.7 kB ? eta 0:00:00
# Collecting dynaconf>=3.2.4
#   Downloading dynaconf-3.2.11-py2.py3-none-any.whl (236 kB)
#      ---------------------------------------- 0.0/236.5 kB ? eta -:--:--
#      ------------------------------------- 236.5/236.5 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.14 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cryptography>=43.0.1->evidently==0.7.14) (1.17.1)
# Requirement already satisfied: packaging in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from deprecation>=2.1.0->evidently==0.7.14) (25.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting distro
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting filelock
#   Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Collecting polyfactory>=2.6.3
#   Downloading polyfactory-2.22.2-py3-none-any.whl (63 kB)
#      ---------------------------------------- 0.0/63.7 kB ? eta -:--:--
#      ---------------------------------------- 63.7/63.7 kB 3.3 MB/s eta 0:00:00
# Collecting litestar-htmx>=0.4.0
#   Downloading litestar_htmx-0.5.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: exceptiongroup in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from litestar>=2.8.3->evidently==0.7.14) (1.3.0)
# Collecting msgspec>=0.18.2
#   Downloading msgspec-0.19.0-cp310-cp310-win_amd64.whl (186 kB)
#      ---------------------------------------- 0.0/186.2 kB ? eta -:--:--
#      ---------------------------------------- 186.2/186.2 kB ? eta 0:00:00
# Collecting multipart>=1.2.0
#   Downloading multipart-1.3.0-py3-none-any.whl (14 kB)
# Collecting rich-click
#   Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Collecting httpx>=0.22
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#      ---------------------------------------- 73.5/73.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio>=3 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from litestar>=2.8.3->evidently==0.7.14) (4.10.0)
# Collecting click
#   Downloading click-8.2.1-py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#      -------------------------------------- 102.2/102.2 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from litestar>=2.8.3->evidently==0.7.14) (4.14.0)
# Collecting multidict>=6.0.2
#   Downloading multidict-6.6.4-cp310-cp310-win_amd64.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# Requirement already satisfied: joblib in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk>=3.6.7->evidently==0.7.14) (1.5.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2025.9.1-cp310-cp310-win_amd64.whl (276 kB)
#      ---------------------------------------- 0.0/276.1 kB ? eta -:--:--
#      ------------------------------------- 276.1/276.1 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk>=3.6.7->evidently==0.7.14) (4.67.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.14) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.14) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas[parquet]>=1.3.5->evidently==0.7.14) (2025.2)
# Collecting pyarrow>=10.0.1
#   Downloading pyarrow-21.0.0-cp310-cp310-win_amd64.whl (26.2 MB)
#      ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#      -- ------------------------------------- 1.8/26.2 MB 39.0 MB/s eta 0:00:01
#      ---- ----------------------------------- 3.3/26.2 MB 34.5 MB/s eta 0:00:01
#      ------- -------------------------------- 4.7/26.2 MB 33.0 MB/s eta 0:00:01
#      --------- ------------------------------ 6.0/26.2 MB 34.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 7.4/26.2 MB 33.8 MB/s eta 0:00:01
#      ------------- -------------------------- 9.0/26.2 MB 33.6 MB/s eta 0:00:01
#      ---------------- ---------------------- 10.9/26.2 MB 32.8 MB/s eta 0:00:01
#      ------------------ -------------------- 12.4/26.2 MB 31.2 MB/s eta 0:00:01
#      --------------------- ----------------- 14.2/26.2 MB 32.8 MB/s eta 0:00:01
#      ----------------------- --------------- 16.0/26.2 MB 34.4 MB/s eta 0:00:01
#      -------------------------- ------------ 17.6/26.2 MB 34.4 MB/s eta 0:00:01
#      ---------------------------- ---------- 19.4/26.2 MB 36.3 MB/s eta 0:00:01
#      ------------------------------- ------- 21.1/26.2 MB 36.3 MB/s eta 0:00:01
#      --------------------------------- ----- 22.8/26.2 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------ -- 24.5/26.2 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  26.2/26.2 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  26.2/26.2 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  26.2/26.2 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------  26.2/26.2 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------- 26.2/26.2 MB 21.8 MB/s eta 0:00:00
# Collecting tenacity>=6.2.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ------------------- -------------------- 0.9/2.0 MB 29.7 MB/s eta 0:00:01
#      ---------------------------------------  1.9/2.0 MB 24.8 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 17.7 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.32.0->evidently==0.7.14) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.32.0->evidently==0.7.14) (3.4.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich>=13->evidently==0.7.14) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
#      ---------------------------------------- 0.0/87.3 kB ? eta -:--:--
#      ---------------------------------------- 87.3/87.3 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn>=1.0.1->evidently==0.7.14) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels>=0.12.2->evidently==0.7.14) (1.0.1)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Collecting h11>=0.8
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.1.0-cp310-cp310-win_amd64.whl (292 kB)
#      ---------------------------------------- 0.0/292.2 kB ? eta -:--:--
#      ------------------------------------- 292.2/292.2 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: colorama>=0.4 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from uvicorn[standard]>=0.22.0->evidently==0.7.14) (0.4.6)
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
#      ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#      ---------------------------------------- 176.8/176.8 kB ? eta 0:00:00
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp310-cp310-win_amd64.whl (88 kB)
#      ---------------------------------------- 0.0/88.3 kB ? eta -:--:--
#      ---------------------------------------- 88.3/88.3 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.7.14) (1.3.1)
# Requirement already satisfied: pycparser in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.14->cryptography>=43.0.1->evidently==0.7.14) (2.22)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#      ---------------------------------------- 78.8/78.8 kB ? eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting faker>=5.0.0
#   Downloading faker-37.6.0-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#      ---------------------------------------  1.9/1.9 MB 41.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 41.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas[parquet]>=1.3.5->evidently==0.7.14) (1.17.0)
# Installing collected packages: appdirs, websockets, watchdog, uuid6, ujson, typing-inspection, tenacity, shellingham, regex, python-dotenv, pydantic-core, pyarrow, mypy-extensions, multipart, multidict, msgspec, mdurl, litestar-htmx, httptools, h11, fsspec, filelock, faker, dynaconf, distro, deprecation, click, annotated-types, uvicorn, typing-inspect, pydantic, polyfactory, plotly, nltk, markdown-it-py, iterative-telemetry, httpcore, cryptography, watchfiles, rich, httpx, typer, rich-click, litestar, evidently
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.3.0
#     Uninstalling plotly-6.3.0:
#       Successfully uninstalled plotly-6.3.0
# Successfully installed annotated-types-0.7.0 appdirs-1.4.4 click-8.2.1 cryptography-45.0.7 deprecation-2.1.0 distro-1.9.0 dynaconf-3.2.11 evidently-0.7.14 faker-37.6.0 filelock-3.19.1 fsspec-2025.9.0 h11-0.16.0 httpcore-1.0.9 httptools-0.6.4 httpx-0.28.1 iterative-telemetry-0.0.10 litestar-2.17.0 litestar-htmx-0.5.0 markdown-it-py-4.0.0 mdurl-0.1.2 msgspec-0.19.0 multidict-6.6.4 multipart-1.3.0 mypy-extensions-1.1.0 nltk-3.9.1 plotly-5.24.1 polyfactory-2.22.2 pyarrow-21.0.0 pydantic-2.11.7 pydantic-core-2.33.2 python-dotenv-1.1.1 regex-2025.9.1 rich-14.1.0 rich-click-1.8.9 shellingham-1.5.4 tenacity-9.1.2 typer-0.17.4 typing-inspect-0.9.0 typing-inspection-0.4.1 ujson-5.11.0 uuid6-2025.0.1 uvicorn-0.35.0 watchdog-6.0.0 watchfiles-1.1.0 websockets-15.0.1
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: C:\Users\frncc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting alibi-detect
#   Downloading alibi_detect-0.12.0-py3-none-any.whl (381 kB)
#      ---------------------------------------- 0.0/381.5 kB ? eta -:--:--
#      ------------------------------------- 381.5/381.5 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.7.1)
# Collecting pyod
#   Downloading pyod-2.0.5-py3-none-any.whl (200 kB)
#      ---------------------------------------- 0.0/200.6 kB ? eta -:--:--
#      ---------------------------------------- 200.6/200.6 kB ? eta 0:00:00
# Requirement already satisfied: river in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.22.0)
# Collecting hotelling
#   Downloading hotelling-0.5.0-py2.py3-none-any.whl (13 kB)
# Collecting opencv-python<5.0.0,>=3.2.0
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#      ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#      - -------------------------------------- 1.3/39.0 MB 42.9 MB/s eta 0:00:01
#      -- ------------------------------------- 2.7/39.0 MB 28.3 MB/s eta 0:00:02
#      ---- ----------------------------------- 4.0/39.0 MB 28.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 5.2/39.0 MB 30.0 MB/s eta 0:00:02
#      ------ --------------------------------- 6.8/39.0 MB 29.1 MB/s eta 0:00:02
#      -------- ------------------------------- 8.1/39.0 MB 30.6 MB/s eta 0:00:02
#      --------- ------------------------------ 9.6/39.0 MB 30.8 MB/s eta 0:00:01
#      ----------- --------------------------- 11.3/39.0 MB 31.2 MB/s eta 0:00:01
#      ------------- ------------------------- 13.2/39.0 MB 34.4 MB/s eta 0:00:01
#      --------------- ----------------------- 15.2/39.0 MB 36.4 MB/s eta 0:00:01
#      ---------------- ---------------------- 16.9/39.0 MB 36.4 MB/s eta 0:00:01
#      ------------------ -------------------- 18.8/39.0 MB 38.5 MB/s eta 0:00:01
#      -------------------- ------------------ 20.6/39.0 MB 40.9 MB/s eta 0:00:01
#      ---------------------- ---------------- 22.3/39.0 MB 38.6 MB/s eta 0:00:01
#      ------------------------ -------------- 24.4/39.0 MB 40.9 MB/s eta 0:00:01
#      ------------------------ -------------- 24.9/39.0 MB 38.5 MB/s eta 0:00:01
#      ------------------------- ------------- 25.7/39.0 MB 34.6 MB/s eta 0:00:01
#      ---------------------------- ---------- 28.3/39.0 MB 34.4 MB/s eta 0:00:01
#      ------------------------------ -------- 30.3/39.0 MB 34.4 MB/s eta 0:00:01
#      -------------------------------- ------ 32.3/39.0 MB 36.3 MB/s eta 0:00:01
#      ---------------------------------- ---- 34.2/39.0 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------ -- 36.1/39.0 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------- - 37.8/39.0 MB 43.5 MB/s eta 0:00:01
#      --------------------------------------  39.0/39.0 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  39.0/39.0 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 39.0/39.0 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0.0,>=1.3.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (1.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.28.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (4.67.1)
# Collecting numba!=0.54.0,<0.60.0,>=0.50.0
#   Downloading numba-0.59.1-cp310-cp310-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      --------------- ------------------------ 1.0/2.7 MB 68.9 MB/s eta 0:00:01
#      --------------- ------------------------ 1.0/2.7 MB 68.9 MB/s eta 0:00:01
#      --------------- ------------------------ 1.0/2.7 MB 68.9 MB/s eta 0:00:01
#      ------------------------------- -------- 2.1/2.7 MB 13.3 MB/s eta 0:00:01
#      ------------------------------- -------- 2.1/2.7 MB 13.3 MB/s eta 0:00:01
#      ------------------------------- -------- 2.1/2.7 MB 13.3 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 MB 9.0 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.0.0
#   Downloading transformers-4.56.1-py3-none-any.whl (11.6 MB)
#      ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#      ------ --------------------------------- 2.0/11.6 MB 43.2 MB/s eta 0:00:01
#      ------------- -------------------------- 4.0/11.6 MB 43.3 MB/s eta 0:00:01
#      -------------------- ------------------- 5.8/11.6 MB 41.5 MB/s eta 0:00:01
#      -------------------------- ------------- 7.7/11.6 MB 44.7 MB/s eta 0:00:01
#      ---------------------------------- ----- 9.9/11.6 MB 45.2 MB/s eta 0:00:01
#      --------------------------------------  11.6/11.6 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------- 11.6/11.6 MB 36.4 MB/s eta 0:00:00
# Collecting toml<1.0.0,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (2.3.2)
# Collecting dill<0.4.0,>=0.3.0
#   Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#      ---------------------------------------- 0.0/119.4 kB ? eta -:--:--
#      ---------------------------------------- 119.4/119.4 kB ? eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=1.8.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (2.11.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (4.14.0)
# Collecting scikit-image<0.23,>=0.19
#   Downloading scikit_image-0.22.0-cp310-cp310-win_amd64.whl (24.5 MB)
#      ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#      -- ------------------------------------- 1.7/24.5 MB 53.2 MB/s eta 0:00:01
#      ------ --------------------------------- 3.7/24.5 MB 47.9 MB/s eta 0:00:01
#      --------- ------------------------------ 5.8/24.5 MB 46.0 MB/s eta 0:00:01
#      ------------ --------------------------- 7.7/24.5 MB 44.9 MB/s eta 0:00:01
#      --------------- ------------------------ 9.7/24.5 MB 44.2 MB/s eta 0:00:01
#      ------------------ -------------------- 11.5/24.5 MB 40.9 MB/s eta 0:00:01
#      --------------------- ----------------- 13.4/24.5 MB 40.9 MB/s eta 0:00:01
#      --------------------- ----------------- 13.7/24.5 MB 36.4 MB/s eta 0:00:01
#      ------------------------ -------------- 15.6/24.5 MB 34.4 MB/s eta 0:00:01
#      --------------------------- ----------- 17.4/24.5 MB 34.4 MB/s eta 0:00:01
#      ------------------------------ -------- 19.3/24.5 MB 34.4 MB/s eta 0:00:01
#      --------------------------------- ----- 21.0/24.5 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------ -- 23.0/24.5 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------  24.5/24.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.5/24.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 24.5/24.5 MB 31.2 MB/s eta 0:00:00
# Collecting Pillow<11.0.0,>=5.4.1
#   Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#      --------------------------------- ------ 2.1/2.6 MB 45.1 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 MB 41.0 MB/s eta 0:00:00
# Collecting catalogue<3.0.0,>=2.0.0
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting numpy<2.0.0,>=1.16.2
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ----- ---------------------------------- 2.1/15.8 MB 44.2 MB/s eta 0:00:01
#      ---------- ----------------------------- 4.1/15.8 MB 52.1 MB/s eta 0:00:01
#      --------------- ------------------------ 6.1/15.8 MB 43.4 MB/s eta 0:00:01
#      -------------------- ------------------- 8.0/15.8 MB 42.5 MB/s eta 0:00:01
#      ------------------------ --------------- 9.8/15.8 MB 45.0 MB/s eta 0:00:01
#      ---------------------------- ---------- 11.6/15.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------- ----- 13.5/15.8 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------- - 15.3/15.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (3.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from alibi-detect) (2.32.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hotelling) (8.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (4.59.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (3.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.4.9)
# Collecting llvmlite<0.43,>=0.42.0dev0
#   Downloading llvmlite-0.42.0-cp310-cp310-win_amd64.whl (28.1 MB)
#      ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#      - -------------------------------------- 1.0/28.1 MB 64.6 MB/s eta 0:00:01
#      - -------------------------------------- 1.0/28.1 MB 64.6 MB/s eta 0:00:01
#      -- ------------------------------------- 1.6/28.1 MB 12.9 MB/s eta 0:00:03
#      -- ------------------------------------- 2.1/28.1 MB 14.7 MB/s eta 0:00:02
#      -- ------------------------------------- 2.1/28.1 MB 14.7 MB/s eta 0:00:02
#      --- ------------------------------------ 2.5/28.1 MB 9.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.1/28.1 MB 10.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.1/28.1 MB 10.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 3.1/28.1 MB 10.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.2/28.1 MB 9.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.2/28.1 MB 9.2 MB/s eta 0:00:03
#      ----- ---------------------------------- 4.2/28.1 MB 9.2 MB/s eta 0:00:03
#      ------- -------------------------------- 5.2/28.1 MB 9.1 MB/s eta 0:00:03
#      ------- -------------------------------- 5.2/28.1 MB 9.1 MB/s eta 0:00:03
#      ------- -------------------------------- 5.5/28.1 MB 8.0 MB/s eta 0:00:03
#      -------- ------------------------------- 6.3/28.1 MB 8.9 MB/s eta 0:00:03
#      -------- ------------------------------- 6.3/28.1 MB 8.9 MB/s eta 0:00:03
#      --------- ------------------------------ 6.8/28.1 MB 8.2 MB/s eta 0:00:03
#      ---------- ----------------------------- 7.3/28.1 MB 8.7 MB/s eta 0:00:03
#      ---------- ----------------------------- 7.3/28.1 MB 8.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 8.3/28.1 MB 8.6 MB/s eta 0:00:03
#      ----------- ---------------------------- 8.4/28.1 MB 8.6 MB/s eta 0:00:03
#      ----------- ---------------------------- 8.4/28.1 MB 8.6 MB/s eta 0:00:03
#      ------------- -------------------------- 9.4/28.1 MB 8.6 MB/s eta 0:00:03
#      ------------- -------------------------- 9.4/28.1 MB 8.6 MB/s eta 0:00:03
#      ------------- -------------------------- 9.6/28.1 MB 7.9 MB/s eta 0:00:03
#      -------------- ------------------------- 10.5/28.1 MB 8.4 MB/s eta 0:00:03
#      -------------- ------------------------- 10.5/28.1 MB 8.4 MB/s eta 0:00:03
#      --------------- ------------------------ 10.7/28.1 MB 7.6 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ---------------- ----------------------- 11.5/28.1 MB 8.3 MB/s eta 0:00:03
#      ----------------- ---------------------- 12.6/28.1 MB 6.5 MB/s eta 0:00:03
#      ----------------- ---------------------- 12.6/28.1 MB 6.5 MB/s eta 0:00:03
#      ----------------- ---------------------- 12.6/28.1 MB 6.5 MB/s eta 0:00:03
#      ------------------- -------------------- 13.6/28.1 MB 6.5 MB/s eta 0:00:03
#      ------------------- -------------------- 13.6/28.1 MB 6.5 MB/s eta 0:00:03
#      ------------------- -------------------- 13.6/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      -------------------- ------------------- 14.7/28.1 MB 6.5 MB/s eta 0:00:03
#      ---------------------- ----------------- 15.7/28.1 MB 6.0 MB/s eta 0:00:03
#      ---------------------- ----------------- 15.7/28.1 MB 6.0 MB/s eta 0:00:03
#      ---------------------- ----------------- 16.0/28.1 MB 5.6 MB/s eta 0:00:03
#      ----------------------- ---------------- 16.8/28.1 MB 6.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 16.8/28.1 MB 6.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 16.8/28.1 MB 6.0 MB/s eta 0:00:02
#      ------------------------- -------------- 17.8/28.1 MB 6.0 MB/s eta 0:00:02
#      ------------------------- -------------- 17.8/28.1 MB 6.0 MB/s eta 0:00:02
#      ------------------------- -------------- 18.1/28.1 MB 5.6 MB/s eta 0:00:02
#      -------------------------- ------------- 18.9/28.1 MB 6.0 MB/s eta 0:00:02
#      -------------------------- ------------- 18.9/28.1 MB 6.0 MB/s eta 0:00:02
#      -------------------------- ------------- 18.9/28.1 MB 6.0 MB/s eta 0:00:02
#      ---------------------------- ----------- 19.9/28.1 MB 5.8 MB/s eta 0:00:02
#      ---------------------------- ----------- 19.9/28.1 MB 5.8 MB/s eta 0:00:02
#      ---------------------------- ----------- 19.9/28.1 MB 5.8 MB/s eta 0:00:02
#      ----------------------------- ---------- 21.0/28.1 MB 5.9 MB/s eta 0:00:02
#      ----------------------------- ---------- 21.0/28.1 MB 5.9 MB/s eta 0:00:02
#      ------------------------------ --------- 21.3/28.1 MB 5.5 MB/s eta 0:00:02
#      ------------------------------- -------- 22.0/28.1 MB 7.4 MB/s eta 0:00:01
#      ------------------------------- -------- 22.0/28.1 MB 7.4 MB/s eta 0:00:01
#      -------------------------------- ------- 22.9/28.1 MB 7.4 MB/s eta 0:00:01
#      -------------------------------- ------- 23.1/28.1 MB 7.4 MB/s eta 0:00:01
#      -------------------------------- ------- 23.1/28.1 MB 7.4 MB/s eta 0:00:01
#      --------------------------------- ------ 23.7/28.1 MB 6.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 24.3/28.1 MB 6.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 25.2/28.1 MB 7.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 25.2/28.1 MB 7.3 MB/s eta 0:00:01
#      ------------------------------------ --- 25.5/28.1 MB 6.8 MB/s eta 0:00:01
#      ------------------------------------- -- 26.2/28.1 MB 7.3 MB/s eta 0:00:01
#      ------------------------------------- -- 26.2/28.1 MB 7.3 MB/s eta 0:00:01
#      -------------------------------------- - 26.8/28.1 MB 6.7 MB/s eta 0:00:01
#      -------------------------------------- - 27.3/28.1 MB 7.4 MB/s eta 0:00:01
#      -------------------------------------- - 27.3/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  28.0/28.1 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  28.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  28.1/28.1 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------- 28.1/28.1 MB 6.9 MB/s eta 0:00:00
# Collecting opencv-python<5.0.0,>=3.2.0
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#      ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#      - -------------------------------------- 1.1/39.5 MB 23.1 MB/s eta 0:00:02
#      -- ------------------------------------- 2.8/39.5 MB 35.6 MB/s eta 0:00:02
#      ---- ----------------------------------- 4.5/39.5 MB 36.2 MB/s eta 0:00:01
#      ------ --------------------------------- 6.3/39.5 MB 36.7 MB/s eta 0:00:01
#      -------- ------------------------------- 8.3/39.5 MB 37.6 MB/s eta 0:00:01
#      ---------- ---------------------------- 10.1/39.5 MB 38.1 MB/s eta 0:00:01
#      ----------- --------------------------- 11.9/39.5 MB 40.9 MB/s eta 0:00:01
#      ------------- ------------------------- 13.9/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------- ----------------------- 15.9/39.5 MB 40.9 MB/s eta 0:00:01
#      ----------------- --------------------- 17.7/39.5 MB 40.9 MB/s eta 0:00:01
#      ------------------- ------------------- 19.7/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------------- ----------------- 21.8/39.5 MB 43.7 MB/s eta 0:00:01
#      ----------------------- --------------- 23.7/39.5 MB 40.9 MB/s eta 0:00:01
#      ------------------------- ------------- 25.6/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------- ----------- 27.5/39.5 MB 40.9 MB/s eta 0:00:01
#      ----------------------------- --------- 29.4/39.5 MB 40.9 MB/s eta 0:00:01
#      ------------------------------ -------- 31.3/39.5 MB 43.7 MB/s eta 0:00:01
#      -------------------------------- ------ 33.2/39.5 MB 43.5 MB/s eta 0:00:01
#      ---------------------------------- ---- 35.2/39.5 MB 43.5 MB/s eta 0:00:01
#      ------------------------------------ -- 37.4/39.5 MB 43.5 MB/s eta 0:00:01
#      --------------------------------------  39.4/39.5 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  39.5/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  39.5/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  39.5/39.5 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------- 39.5/39.5 MB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<3.0.0,>=1.0.0->alibi-detect) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<3.0.0,>=1.0.0->alibi-detect) (2025.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (2.33.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=1.8.0->alibi-detect) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (3.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2025.8.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3.0.0,>=2.21.0->alibi-detect) (2.5.0)
# Collecting imageio>=2.27
#   Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#      ---------------------------------------- 0.0/315.8 kB ? eta -:--:--
#      ------------------------------------- 315.8/315.8 kB 19.1 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
#      ---------------------------------------- 0.0/226.5 kB ? eta -:--:--
#      ------------------------------------- 226.5/226.5 kB 13.5 MB/s eta 0:00:00
# Collecting networkx>=2.8
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------  1.7/1.7 MB 55.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 37.2 MB/s eta 0:00:00
# Collecting lazy_loader>=0.3
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: colorama in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm<5.0.0,>=4.28.1->alibi-detect) (0.4.6)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
#      ---------------------------------------- 0.0/320.2 kB ? eta -:--:--
#      ------------------------------------- 320.2/320.2 kB 19.4 MB/s eta 0:00:00
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.0-cp39-abi3-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      ---------------- ----------------------- 1.1/2.7 MB 23.3 MB/s eta 0:00:01
#      ------------------------------- -------- 2.1/2.7 MB 22.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 MB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (2025.9.1)
# Collecting huggingface-hub<1.0,>=0.34.0
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#      ---------------------------------------- 0.0/561.5 kB ? eta -:--:--
#      ------------------------------------- 561.5/561.5 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (6.0.2)
# Requirement already satisfied: filelock in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from transformers<5.0.0,>=4.0.0->alibi-detect) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0,>=4.0.0->alibi-detect) (2025.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.0->alibi-detect) (1.17.0)
# Installing collected packages: toml, safetensors, Pillow, numpy, networkx, llvmlite, lazy_loader, dill, catalogue, tifffile, opencv-python, numba, imageio, huggingface-hub, tokenizers, scikit-image, transformers, pyod, hotelling, alibi-detect
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed Pillow-10.4.0 alibi-detect-0.12.0 catalogue-2.0.10 dill-0.3.9 hotelling-0.5.0 huggingface-hub-0.34.4 imageio-2.37.0 lazy_loader-0.4 llvmlite-0.42.0 networkx-3.4.2 numba-0.59.1 numpy-1.26.4 opencv-python-4.11.0.86 pyod-2.0.5 safetensors-0.6.2 scikit-image-0.22.0 tifffile-2025.5.10 tokenizers-0.22.0 toml-0.10.2 transformers-4.56.1
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: C:\Users\frncc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.10.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\frncc\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: C:\Users\frncc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1) Configuración rápida

# %%
from __future__ import annotations
import pandas as pd
import numpy as np
from pathlib import Path

# === Ajusta aquí si deseas otro archivo o ruta ===
CSV_PATH = Path('../df_procesados/df_planta_2.csv')
# Ventanas y paso
WIN_MIN   = '30min'   # tamaño de ventana móvil
STEP_MIN  = '10min'   # paso entre ventanas

# Baseline: por defecto, primeras 2 semanas del dataset
BASELINE_DAYS = 14

# Semáforo (puedes refinar según tu planta)
PSI_WARN, PSI_ALARM = 0.10, 0.25
KS_P_ALARM = 0.01

# Opcional: forzar nombre de columna datetime si lo conoces
FORCED_DT_COL = None  # e.g., 'date_time'

# %% [markdown]
# ## 2) Carga de datos y detección automática de columnas (fecha, numéricas y KPI)

# %%
def infer_datetime_col(df: pd.DataFrame, forced: str | None = None) -> str:
    if forced and forced in df.columns:
        return forced
    # candidatos por nombre
    name_cands = [c for c in df.columns if str(c).lower() in (
        'date_time', 'datetime', 'timestamp', 'fecha', 'fechahora', 'time')]
    for c in name_cands:
        try:
            pd.to_datetime(df[c])
            return c
        except Exception:
            pass
    # fallback: probar todas las columnas
    for c in df.columns:
        try:
            pd.to_datetime(df[c])
            return c
        except Exception:
            continue
    raise ValueError('No se pudo inferir columna temporal. Especifica FORCED_DT_COL.')

def detect_kpi_cols(cols: list[str]) -> list[str]:
    # heurística: buscar nombres con turbidez/pH clarificado/efluente/kpi
    keys = ['turbidez', 'clarificado', 'kpi', 'efluente', 'salida']
    return [c for c in cols if any(k in str(c).lower() for k in keys)]

raw = pd.read_csv(CSV_PATH)
raw['date_time'] = pd.to_datetime(raw['date_time'])
dt_col = infer_datetime_col(raw, FORCED_DT_COL)
raw[dt_col] = pd.to_datetime(raw[dt_col], errors='coerce')
raw = raw.dropna(subset=[dt_col]).sort_values(dt_col).set_index(dt_col)

num_cols = raw.select_dtypes(include=['number']).columns.tolist()
kpi_cands = detect_kpi_cols(num_cols)
kpi_col = kpi_cands[0] if kpi_cands else None

print('Columna tiempo:', dt_col)
print('Columnas numéricas ({}):'.format(len(num_cols)))
print(num_cols)
print('KPI detectado:', kpi_col)

df = raw.copy()
start, end = df.index.min(), df.index.max()
bl_end = start + pd.Timedelta(days=BASELINE_DAYS)
base = df.loc[start:bl_end]
cur  = df.loc[bl_end:]
print('Baseline:', start, '→', bl_end, '| Actual:', bl_end, '→', end)
# Out:
# Columna tiempo: date_time
# Columnas numéricas (12):
# ['Flujo Cámara de contacto 1', 'Flujo Salida de Lodo Sedimentador Secundario 3', 'Flujo Aire Reactor 2', 'Nivel Pozo WAS', 'Flujo Afluente PTAR', 'Flujo Alimentación Digestor 1', 'Flujo Alimentación Digestor 2', 'Flujo Alimentación Digestor 3', 'Flujo Aire Reactor 1', 'Flujo Aire Reactor 3', 'OD Reactor 1', 'Flujo Cámara de contacto 2']
# KPI detectado: Flujo Salida de Lodo Sedimentador Secundario 3
# Baseline: 2024-08-12 16:32:00 → 2024-08-26 16:32:00 | Actual: 2024-08-26 16:32:00 → 2025-08-09 23:59:00

# %% [markdown]
# ## 3) Drift Univariado (Evidently) — PSI/KS/AD y Reporte HTML

# %%
from evidently import Report
from evidently.presets import DataDriftPreset
from evidently.metrics import ValueDrift, DriftedColumnsCount

ref = base.copy()
cur = cur.copy()
cols = list(ref.columns)

# Construcción de métricas (preset + univariado + conteo de columnas derivadas)
metrics = [
    DataDriftPreset(),               # preset de drift a nivel dataset
    DriftedColumnsCount(),           # conteo de columnas con drift
    *[ValueDrift(column=c) for c in cols]  # drift univariado por columna
]

report = Report(metrics=metrics)

# Ejecutar reporte
snap = report.run(
    reference_data=ref.reset_index(drop=True),
    current_data=cur.reset_index(drop=True),
)

# Guardar HTML y JSON desde el snapshot (no desde Report)
snap.save_html("planta2_univar.html")
with open("planta2_univar.json", "w", encoding="utf-8") as f:
    f.write(snap.json())            # o json.dump(snap.dict(), f, indent=2, ensure_ascii=False)

print("OK -> planta2_univar.html y planta2_univar.json")
# Out:
# OK -> planta2_univar.html y planta2_univar.json

# %% [markdown]
# ## 4) Drift Multivariado — MMD (alibi-detect)

# %%
from alibi_detect.cd import MMDDrift

x_ref = base[num_cols].dropna().values
mmd = MMDDrift(x_ref, p_val=0.01, kernel='rbf')

def mmd_on_window(df_win):
    X = df_win[num_cols].dropna().values
    if len(X) < 20:
        return {'p_val': 1.0, 'is_drift': 0, 'distance': 0.0}
    res = mmd.predict(X, return_p_val=True, return_distance=True)
    return {
        'p_val': float(res['data']['p_val']),
        'is_drift': int(res['data']['is_drift']),
        'distance': float(res['data']['distance'])
    }
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[50], line 4
#       1 from alibi_detect.cd import MMDDrift
#       3 x_ref = base[num_cols].dropna().values
# ----> 4 mmd = MMDDrift(x_ref, p_val=0.01, kernel='rbf')
#       6 def mmd_on_window(df_win):
#       7     X = df_win[num_cols].dropna().values
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\alibi_detect\utils\warnings.py:17, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      14 @functools.wraps(f)
#      15 def wrapper(*args, **kwargs):
#      16     _rename_kwargs(f.__name__, kwargs, aliases)
# ---> 17     return f(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\alibi_detect\cd\mmd.py:97, in MMDDrift.__init__(self, x_ref, backend, p_val, x_ref_preprocessed, preprocess_at_init, update_x_ref, preprocess_fn, kernel, sigma, configure_kernel_from_x_ref, n_permutations, batch_size_permutations, device, input_shape, data_type)
#      89 self._set_config(locals())
#      91 backend = backend.lower()
#      92 BackendValidator(
#      93     backend_options={Framework.TENSORFLOW: [Framework.TENSORFLOW],
#      94                      Framework.PYTORCH: [Framework.PYTORCH],
#      95                      Framework.KEOPS: [Framework.KEOPS]},
#      96     construct_name=self.__class__.__name__
# ---> 97 ).verify_backend(backend)
#      99 kwargs = locals()
#     100 args = [kwargs['x_ref']]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\alibi_detect\utils\frameworks.py:103, in BackendValidator.verify_backend(self, backend)
#     100         missing_deps.append(dependency)
#     102 if missing_deps:
# --> 103     self._raise_import_error(missing_deps, backend)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\alibi_detect\utils\frameworks.py:116, in BackendValidator._raise_import_error(self, missing_deps, backend)
#     111 error_msg = (f'{missing_deps_str} not installed. Cannot initialize and run {self.construct_name} '
#     112              f'with {backend} backend.')
#     113 pip_msg = '' if not optional_dependencies else \
#     114     (f'The necessary missing dependencies can be installed using '
#     115      f'`pip install alibi-detect[{" ".join(optional_dependencies)}]`.')
# --> 116 raise ImportError(f'{error_msg} {pip_msg}')
#
# ImportError: `tensorflow` not installed. Cannot initialize and run MMDDrift with tensorflow backend. The necessary missing dependencies can be installed using `pip install alibi-detect[tensorflow]`.

# %% [markdown]
# ## 5) PCA → Hotelling T² y Q (SPE)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

Xb = base[num_cols].dropna()
scaler = StandardScaler().fit(Xb)
Zb = scaler.transform(Xb)
pca = PCA().fit(Zb)

def t2_q_window(df_win):
    Xw = df_win[num_cols].dropna()
    if Xw.empty:
        return np.nan, np.nan
    Zw = scaler.transform(Xw)
    scores = pca.transform(Zw)
    var = np.var(scores, axis=0, ddof=1)
    var[var == 0] = 1e-9
    T2_inst = np.sum((scores**2) / var, axis=1)
    T2_mean = float(np.mean(T2_inst))
    Zw_rec = pca.inverse_transform(scores)
    resid = Zw - Zw_rec
    Q = float(np.mean(np.sum(resid**2, axis=1)))
    return T2_mean, Q
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 5
#       2 from sklearn.preprocessing import StandardScaler
#       4 Xb = base[num_cols].dropna()
# ----> 5 scaler = StandardScaler().fit(Xb)
#       6 Zb = scaler.transform(Xb)
#       7 pca = PCA().fit(Zb)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_data.py:907, in StandardScaler.fit(self, X, y, sample_weight)
#     905 # Reset internal state before fitting
#     906 self._reset()
# --> 907 return self.partial_fit(X, y, sample_weight)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_data.py:943, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     911 """Online computation of mean and std on X for later scaling.
#     912
#     913 All of X is processed as a single batch. This is intended for cases
#    (...)
#     940     Fitted scaler.
#     941 """
#     942 first_call = not hasattr(self, "n_samples_seen_")
# --> 943 X = validate_data(
#     944     self,
#     945     X,
#     946     accept_sparse=("csr", "csc"),
#     947     dtype=FLOAT_DTYPES,
#     948     ensure_all_finite="allow-nan",
#     949     reset=first_call,
#     950 )
#     951 n_features = X.shape[1]
#     953 if sample_weight is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:1128, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1126     n_samples = _num_samples(array)
#    1127     if n_samples < ensure_min_samples:
# -> 1128         raise ValueError(
#    1129             "Found array with %d sample(s) (shape=%s) while a"
#    1130             " minimum of %d is required%s."
#    1131             % (n_samples, array.shape, ensure_min_samples, context)
#    1132         )
#    1134 if ensure_min_features > 0 and array.ndim == 2:
#    1135     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 15)) while a minimum of 1 is required by StandardScaler.

# %% [markdown]
# ## 6) KPI / Concept Drift — Page–Hinkley (si existe KPI detectado)

# %%
from river.drift import PageHinkley

if kpi_col is not None:
    ph = PageHinkley(min_instances=30, delta=0.005, threshold=50.0, alpha=0.9999)
    flags = []
    idxs = []
    for ts, v in cur[kpi_col].dropna().items():
        ph.update(v)
        flags.append(ph.change_detected)
        idxs.append(ts)
        if ph.change_detected:
            ph.reset()
    kpi_flags = pd.Series(flags, index=idxs, dtype=bool)
    kpi_flags.to_frame('PH_change').to_csv('planta1_kpi_ph.csv')
    print('Guardado: planta1_kpi_ph.csv')
else:
    print('No se detectó KPI; se omite Page–Hinkley.')

# %% [markdown]
# ## 7) Anomalías / Nuevos Regímenes — IsolationForest + LOF (PyOD)

# %%
from sklearn.ensemble import IsolationForest
from pyod.models.lof import LOF

Xb_np = base[num_cols].dropna().values
iforest = IsolationForest(contamination=0.02, random_state=0).fit(Xb_np)
lof = LOF(contamination=0.02).fit(Xb_np)

def outlier_ratios(df_win):
    X = df_win[num_cols].dropna().values
    if len(X) == 0:
        return 0.0, 0.0
    r_if = (iforest.predict(X) == -1).mean()
    r_lof = lof.predict(X).mean()  # 1=outlier
    return float(r_if), float(r_lof)

# %% [markdown]
# ## 8) Bucle por ventanas + Semáforo + Export a CSV

# %%
def sliding_windows(df, win=WIN_MIN, step=STEP_MIN):
    start = df.index.min()
    end = df.index.max()
    t = start
    while t + pd.Timedelta(win) <= end:
        w = df.loc[t: t + pd.Timedelta(win)]
        yield (t, t + pd.Timedelta(win), w)
        t = t + pd.Timedelta(step)

rows = []
for t0, t1, w in sliding_windows(cur):
    mmd_res = mmd_on_window(w)
    T2, Q = t2_q_window(w)
    r_if, r_lof = outlier_ratios(w)

    # Semáforo simple (ajústalo a tu operación):
    level = 'Verde'
    if mmd_res['is_drift'] == 1 or r_if > 0.10 or r_lof > 0.10:
        level = 'Amarillo'
    if (mmd_res['is_drift'] == 1 and (r_if > 0.10 or r_lof > 0.10)) or (not np.isnan(T2) and T2 > 10):
        level = 'Rojo'

    rows.append({
        't_ini': t0, 't_fin': t1,
        'MMD_p': mmd_res['p_val'], 'MMD_is_drift': mmd_res['is_drift'], 'MMD_dist': mmd_res['distance'],
        'T2_mean': T2, 'Q_mean': Q,
        'outlier_iforest': r_if, 'outlier_lof': r_lof,
        'semaforo': level
    })

summary = pd.DataFrame(rows)
summary.to_csv('planta1_ventanas.csv', index=False)
summary.head()

# %% [markdown]
# ## 9) Visualizaciones rápidas (opcional)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,4))
plt.plot(summary['t_fin'], summary['MMD_dist'])
plt.title('Distancia MMD por ventana')
plt.xlabel('Tiempo')
plt.ylabel('MMD distance')
plt.show()

fig = plt.figure(figsize=(12,4))
plt.plot(summary['t_fin'], summary['T2_mean'])
plt.title('T² medio por ventana')
plt.xlabel('Tiempo')
plt.ylabel('T² (promedio)')
plt.show()

fig = plt.figure(figsize=(12,4))
plt.plot(summary['t_fin'], summary['outlier_iforest'], label='IForest')
plt.plot(summary['t_fin'], summary['outlier_lof'], label='LOF')
plt.title('Proporción de outliers por ventana')
plt.xlabel('Tiempo')
plt.ylabel('Ratio outliers')
plt.legend()
plt.show()

fig = plt.figure(figsize=(12,2.5))
y = summary['semaforo'].map({'Verde':0, 'Amarillo':1, 'Rojo':2}).values
plt.step(summary['t_fin'], y, where='post')
plt.yticks([0,1,2], ['Verde','Amarillo','Rojo'])
plt.title('Semáforo por ventana')
plt.xlabel('Tiempo')
plt.show()

# %% [markdown]
# ### Notas y buenas prácticas
# - Revisa `num_cols` y `kpi_col` detectados; si necesitas fijarlos manualmente, edítalos.
# - Ajusta `BASELINE_DAYS`, `WIN_MIN`, `STEP_MIN` y umbrales del semáforo.
# - Usa `planta1_univar.html` para ranking de columnas con mayor drift (PSI/KS/AD).
# - Si el KPI **cambia** sin que MMD marque data drift, investiga **concept drift** (química/setpoints/modelo).
