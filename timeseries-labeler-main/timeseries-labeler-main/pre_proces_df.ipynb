# %%
import pandas as pd
df = pd.read_csv('../../df_procesados/df_planta_1.csv')
df['date_time'] = pd.to_datetime(df['date_time']).dt.strftime('%Y-%m-%dT%H:%M:%S-04:00')
df = df.rename(columns={'date_time': 'timestamp'})
df.to_csv('../../df_procesados/df_planta_1_timeseries.csv', index=False)
df.head()
# Out:
#                    timestamp  Conductividad DAF  \
# 0  2024-08-13T00:00:00-04:00                NaN
# 1  2024-08-14T00:00:00-04:00                NaN
# 2  2024-08-20T00:00:00-04:00                NaN
# 3  2024-08-21T00:00:00-04:00                NaN
# 4  2024-08-27T00:00:00-04:00                NaN
#
#    Flujo Parshall 01 entrada a Ecualizador 1  Flujo de envío a DAF  \
# 0                                        NaN                   NaN
# 1                                        NaN                   NaN
# 2                                        NaN                   NaN
# 3                                        NaN                   NaN
# 4                                        NaN                   NaN
#
#    Nivel Ecualizador 1 (Tk 30m3)  Nivel Ecualizador 2 (Tk 250m3)  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# ...
