# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import scipy.stats as stats
import math
import os
import funciones_pre_procesamiento as funciones

# %%
desc_3 = os.path.join('../Proyecto Herramienta para monitoreo de la calidad de datos/2. Datos/planta_3/planta_3_descripcion.csv')
desc_planta_3 = pd.read_csv(desc_3)

planta_3 = os.path.join('../Proyecto Herramienta para monitoreo de la calidad de datos/2. Datos/planta_3/planta_3_datos.csv')
df_planta_3 = pd.read_csv(planta_3)

# %% [markdown]
# # Limpieza

# %%
df_planta_3.info()
desc_planta_3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22568 entries, 0 to 22567
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date_time                               22568 non-null  object
#  1   Nivel pozo                              21829 non-null  float64
#  2   Falla Pozo                              22565 non-null  float64
#  3   Energía Total Activa Bombas Elevadoras  22350 non-null  float64
#  4   Nivel Pozo                              0 non-null      float64
#  5   Funcionando Pozo                        0 non-null      float64
#  6   Falla Asimetría Pozo                    22350 non-null  float64
#  7   Presión pozo                            22351 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 1.4+ MB
#                                      name    unit       type_var periodicity  \
# ...

# %%
df_planta_3['date_time'] = pd.to_datetime(df_planta_3['date_time'])

df_planta_3.dropna(axis=1, how='all', inplace=True)

on_off_cols = ['Falla Pozo', 'Falla Asimetría Pozo']
for col in on_off_cols:
    df_planta_3[col] = df_planta_3[col].astype(bool)
df_planta_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22568 entries, 0 to 22567
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date_time                               22568 non-null  datetime64[ns]
#  1   Nivel pozo                              21829 non-null  float64
#  2   Falla Pozo                              22568 non-null  bool
#  3   Energía Total Activa Bombas Elevadoras  22350 non-null  float64
#  4   Falla Asimetría Pozo                    22568 non-null  bool
#  5   Presión pozo                            22351 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(3)
# memory usage: 749.5 KB

# %%
df_planta_3.describe()
# Out:
#                            date_time    Nivel pozo  \
# count                          22568  21829.000000
# mean   2025-08-01 22:36:43.742467072      6.591438
# min              2025-07-24 20:54:00      6.020000
# 25%              2025-07-28 21:38:45      6.450000
# 50%              2025-08-01 23:13:30      6.520000
# 75%              2025-08-05 21:20:15      6.560000
# max              2025-08-09 23:59:00     10.780000
# std                              NaN      0.329512
#
#        Energía Total Activa Bombas Elevadoras  Presión pozo
# count                            22350.000000  22351.000000
# mean                               600.633378      2.702661
# min                                598.000000      0.290000
# 25%                                599.000000      0.405000
# 50%                                601.000000      3.750000
# 75%                                602.000000      3.800000
# max                                604.000000      4.350000
# ...

# %% [markdown]
# # Gráficos

# %%
funciones.plot_corr(df_planta_3)

# %%
num_cols = df_planta_3.select_dtypes(include=[np.number]).columns
for col in num_cols:
    wmin, wmax, cmin, cmax = funciones.get_limits(desc_planta_3, col)
    print(f'Graficando {col} (límites: wmin={wmin}, wmax={wmax}, cmin={cmin}, cmax={cmax})')
    funciones.plot_all(df_planta_3, col, warning_min=wmin, warning_max=wmax, critical_min=cmin, critical_max=cmax)
# Out:
# Graficando Nivel pozo (límites: wmin=None, wmax=None, cmin=None, cmax=None)
# Graficando Energía Total Activa Bombas Elevadoras (límites: wmin=None, wmax=None, cmin=None, cmax=None)
# Graficando Presión pozo (límites: wmin=None, wmax=None, cmin=None, cmax=None)

# %%
# Graficar todas las variables numéricas como series de tiempo para planta 3
funciones.plot_all_timeseries(df_planta_3)

# %%
# Crear la carpeta 'df_procesados' si no existe
os.makedirs('df_procesados', exist_ok=True)

# Guardar los dataframes limpios de planta 3 en la carpeta
df_planta_3.to_csv('../df_procesados/df_planta_3.csv', index=False)

# %% [markdown]
# # Lagunas temporales

# %%
columnas_interes = [col for col in df_planta_3.columns if col != "date_time"]
funciones.analizar_columnas_por_fecha(df_planta_3, columnas_interes)
# Out:
# ...
#  Análisis de: 'Nivel pozo'
# ...
#
# Fechas con datos:
# [2025-07-25, 2025-08-09], 16 días
#
# Total fechas con datos: 16 (100.0%)
#
# Fechas sin datos:
#
# Total fechas sin datos: 0 (0.0%)
#
#
# ...
#  Análisis de: 'Falla Pozo'
# ...
#
# Fechas con datos:
# [2025-07-24, 2025-08-09], 17 días
#
# Total fechas con datos: 17 (100.0%)
#
# Fechas sin datos:
#
# Total fechas sin datos: 0 (0.0%)
#
#
# ...
#  Análisis de: 'Energía Total Activa Bombas Elevadoras'
# ...
#
# Fechas con datos:
# [2025-07-25, 2025-08-09], 16 días
#
# Total fechas con datos: 16 (100.0%)
#
# Fechas sin datos:
#
# Total fechas sin datos: 0 (0.0%)
#
#
# ...
#  Análisis de: 'Falla Asimetría Pozo'
# ...
#
# Fechas con datos:
# [2025-07-24, 2025-08-09], 17 días
#
# Total fechas con datos: 17 (100.0%)
#
# Fechas sin datos:
#
# Total fechas sin datos: 0 (0.0%)
#
#
# ...
#  Análisis de: 'Presión pozo'
# ...
#
# Fechas con datos:
# [2025-07-25, 2025-08-09], 16 días
#
# Total fechas con datos: 16 (100.0%)
#
# Fechas sin datos:
#
# Total fechas sin datos: 0 (0.0%)

# %%
num_cols = df_planta_3.select_dtypes(include=[np.number]).columns
l_periodo = []

for col in num_cols:
    
    data = funciones.periocidad_data(df_planta_3, col)

    l_periodo.append({
                "columna": col,
                "promedio_minutos": data["promedio_minutos"],
                "std_minutos": data["std_minutos"],
                "maximo_minutos": data["maximo"]
            })
    
df_periodo = pd.DataFrame(l_periodo)

df_periodo.head()
# Out:
#                                   columna  promedio_minutos  std_minutos  \
# 0                              Nivel pozo          1.022769     2.111191
# 1  Energía Total Activa Bombas Elevadoras          1.029532     2.354087
# 2                            Presión pozo          1.029530     2.354035
#
#    maximo_minutos
# 0           270.0
# 1           270.0
# 2           270.0
